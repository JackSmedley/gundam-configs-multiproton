# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import uproot
import awkward as ak
from scipy import linalg

# %%
InputBaseDir = '/Users/jskim/Documents/Neutrino/ICARUS/GUNDAM/work/Flux/'

#InputFileName = '2023-07-31_out_450.37_7991.98_79512.66_QEL11.root'
InputFileName = '2023-08-17_out_450.37_7991.98_79512.66_QEL11.root'

InputFilePath = '%s/%s'%(InputBaseDir, InputFileName)

HistName = 'covariance_matrices/hadron/total/hcov_total'

# %%
with uproot.open(InputFilePath) as file:
    hcov = file[HistName].to_numpy()[0]

# %%
hcov
# Out:
# array([[ 1.13221904e-02,  1.00277119e-02,  6.81055241e-03, ...,
#          7.33285246e-04, -2.81652548e-05,  1.34337055e-03],
#        [ 1.00277119e-02,  9.23037520e-03,  6.56037739e-03, ...,
#          8.64799359e-04,  6.71983216e-04,  1.83706025e-03],
#        [ 6.81055241e-03,  6.56037739e-03,  5.09901905e-03, ...,
#          7.69617932e-04,  8.55708693e-04,  1.78100748e-03],
#        ...,
#        [ 7.33285246e-04,  8.64799359e-04,  7.69617932e-04, ...,
#          8.73275814e-03,  1.76830806e-02,  1.99139956e-02],
#        [-2.81652548e-05,  6.71983216e-04,  8.55708693e-04, ...,
#          1.76830806e-02,  4.57041581e-02,  5.13863523e-02],
#        [ 1.34337055e-03,  1.83706025e-03,  1.78100748e-03, ...,
#          1.99139956e-02,  5.13863523e-02,  6.10576504e-02]])

# %%
linalg.det(hcov)
# Out:
# -0.0
